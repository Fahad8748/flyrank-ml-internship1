# %%
import os

# -------------------------------------------------------------------
# STEP 1: Ensure directory structure exists
# -------------------------------------------------------------------
os.makedirs("docs", exist_ok=True)

# -------------------------------------------------------------------
# STEP 2: Create docs/content_map.md
# -------------------------------------------------------------------
content_map_md = """# The Through-Line: Content Map & Call-to-Action Strategy — Week 3

> **Core Purpose:** Bridge portfolio messaging to a singular target action: convincing technical hiring managers and engineering leads to interview Fahad for Machine Learning and Data Systems roles.

---

## 1. The One-Line Claim

> **"I build leak-free machine learning pipelines that predict organic search rank drops before production performance degrades."**

---

## 2. Portfolio Content Map"""

with open("docs/content_map.md", "w", encoding="utf-8") as f:
    f.write(content_map_md)

print("File created: docs/content_map.md")
# Out:
# File created: docs/content_map.md
