# %%
import os
import pandas as pd
from sklearn.ensemble import RandomForestClassifier

# -------------------------------------------------------------------
# STEP 1: Create the 'docs' directory
# -------------------------------------------------------------------
os.makedirs("docs", exist_ok=True)
print("Directory 'docs' created/verified.")

# -------------------------------------------------------------------
# STEP 2: Write docs/portfolio_case_study.md
# -------------------------------------------------------------------
case_study_content = """# Voice Card & Portfolio Case Study

**Voice Card**
*Direct, grounded, plain-spoken, evidence-first, zero fluff.*

---

## Before / After Copy Edit

* **Generic AI Line (Before):**
  *"Leveraged advanced machine learning algorithms and predictive modeling paradigms to optimize organic search visibility and maximize synergy across digital assets."*
* **My Edited Version (After):**
  *"Built a model that flags dropping search rankings before traffic falls off, saving editorial teams from wasting time on stable pages."*

---

## Framed Case Study: FlyRank ML Internship Capstone

### 1. The Problem
Organic search traffic follows a steep power-law: a small fraction of high-value pages generate the vast majority of traffic and revenue. Content teams usually realize a page is losing rank weeks after traffic crashes, leaving them reacting to lost revenue instead of preventing it. Manually tracking thousands of daily keyword fluctuations across constantly changing search engine algorithms is impossible.

### 2. What I Did & Decided
* **Framed the Decision:** Focused the project on predicting relative positional risk rather than attempting non-causal ranking predictions. The target unit of analysis is a page-keyword pair per week.
* **Evaluated Baselines:** Compared simple, hand-coded threshold rules (e.g., flagging drops greater than 3 positions) against trained scikit-learn classifiers (Logistic Regression and Random Forest).
* **Prevented Data Leakage:** Identified target leakage traps in baseline feature engineering, specifically excluding downstream trend indicators like direct target derivation columns (`trend_direction`) to keep the evaluation honest.
* **Built Interactive Scoring:** Integrated the model into a lightweight Streamlit dashboard so strategists can input position histories and instantly receive risk scores.

### 3. What Came of It
* **Prioritized Attention:** The top 10% of high-impact pages were isolated from noise, allowing editorial intervention on genuinely volatile pages.
* **Reduced False Alarms:** The machine learning baseline outperformed rigid static rules by reducing false positives, saving developer and editing resources.
* **Deployed Artifact:** Delivered a fully traceable pipeline in GitHub backed by concrete starter data numbers.

---

## Bio & Contact

* **Bio:** Machine Learning Practitioner and Python Developer specializing in computational pipelines, data analysis, and predictive models. Focused on building practical tools that turn noisy data into clear operational decisions.
* **GitHub:** https://github.com/Fahad8748
* **Portfolio / Work:** https://github.com/Fahad8748/flyrank-ml-internship
* **Call to Action:** Looking to collaborate on ML engineering or data analytics pipelines? Reach out via GitHub to discuss project opportunities.
"""

with open("docs/portfolio_case_study.md", "w", encoding="utf-8") as f:
    f.write(case_study_content)
print("File created: docs/portfolio_case_study.md")

# -------------------------------------------------------------------
# STEP 3: Write docs/prompt_iteration_log.md
# -------------------------------------------------------------------
prompt_log_content = """# Prompt Iteration Log: ML Data Leakage & Temporal Audit

## 1. Task Definition
* **FL-01 Target Task:** Audit Python feature engineering code for target leakage, temporal ordering bugs, and cross-entity boundary shifts in page-keyword ranking predictions.

---

## 2. Iteration Log (6 Versions)

### Version 0: Naive Baseline
```text
Help me find data leakage in my machine learning code.
"""
# Out:
# Directory 'docs' created/verified.
# File created: docs/portfolio_case_study.md
