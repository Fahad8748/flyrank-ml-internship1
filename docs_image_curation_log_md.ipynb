# %%
import os

# -------------------------------------------------------------------
# STEP 1: Ensure directory structure exists
# -------------------------------------------------------------------
os.makedirs("docs/images", exist_ok=True)

# -------------------------------------------------------------------
# STEP 2: Create docs/image_curation_log.md
# -------------------------------------------------------------------
curation_log_md = """# Image Curation & Discernment Log — Week 3

> **Core Principle:** Kill your darlings. AI makes generation trivial; engineering judgment dictates what serves as authentic proof versus what is discarded as noise.

---

## 1. Portfolio Image Inventory & Need Mapping

| Asset Role | Asset Type | File Path | Selection Choice |
|---|---|---|---|
| **Author / Profile** | Real Photo | `docs/images/profile_headshot.jpg` | **Real Photo:** Authentic headshot of the engineer to establish personal credibility. |
| **Pipeline Core Work** | Real Capture | `docs/images/pr_curve_proof.png` | **Real Screenshot:** Programmatically generated PR-AUC evaluation curve from actual model output. |
| **Dashboard UI** | Real Capture | `docs/images/streamlit_dashboard.png` | **Real Screenshot:** Live UI capture showing input controls and probability score outputs. |
| **Hero Background** | Generated AI Asset | `docs/images/hero_texture.png` | **AI Generated:** Minimalist dark slate geometric grid texture matching the identity kit palette. |
| **System Flow Diagram** | Real Schema Vector | `docs/images/pipeline_architecture.svg` | **Real Vector:** Directed Graphviz architecture diagram mapping `page_id` temporal splits. |

---

## 2. Calls & Decisions: Real Captures vs. AI Generation

* **Author Profile (Real Photo):** Used a real headshot. Generated AI avatars destroy professional credibility and convey synthetic identity.
* **Model Proof & Metrics (Real Captures):** Used actual Matplotlib/Seaborn vector exports and Streamlit interface captures. AI-generated dashboard mockups produce unreadable, hallucinated gibberish for text and axes, rendering them useless as proof.
* **Connective Texture (AI Generated):** Used AI exclusively for abstract background texture (`hero_texture.png`), maintaining strict prompt constraints to mirror the palette (`#0F172A`, `#1E293B`, `#38BDF8`).

---

## 3. Discernment & Rejection Log (The "Kill Your Darlings" Audit)

### Rejection Case 1: Decorative Abstract 3D Network Nodes
* **Prompt Attempted:** "*3D isometric glowing blue neural network nodes connecting organic search data streams, dark background, hyperrealistic render*"
* **Decision:** **REJECTED**
* **Reasoning:** The generated image looked like generic stock tech art. It added zero proof value to the portfolio and actively violated the framing rule by competing with actual metric charts for visual attention.

### Rejection Case 2: AI-Generated Dashboard Mockup
* **Prompt Attempted:** "*Clean dark mode analytics dashboard showing search ranking position drop probabilities, line graphs, dark slate UI*"
* **Decision:** **REJECTED**
* **Reasoning:** While visually sleek at a distance, inspecting the image revealed hallucinated, non-functional UI controls, scrambled axis labels, and fake metrics. Substituting real code execution outputs with synthetic UI mockups invalidates technical work.

---

## 4. Prompt Consistency Constraints for AI Assets

For background connective assets, prompts were locked to these strict parameters:
```text
Style: Minimalist technical dark slate texture, subtle geometric line grid.
Palette: Strictly #0F172A dark slate background, #1E293B surface accents, #38BDF8 subtle highlight lines.
Constraints: Flat 2D vector, no glowing text, no 3D elements, high contrast, non-distracting background fill.
"""

with open("docs/image_curation_log.md", "w", encoding="utf-8") as f:
    f.write(curation_log_md)

print("File created: docs/image_curation_log.md")
# Out:
# File created: docs/image_curation_log.md
