# %%
import os

# -------------------------------------------------------------------
# STEP 1: Ensure directory structure exists
# -------------------------------------------------------------------
os.makedirs("docs", exist_ok=True)

# -------------------------------------------------------------------
# STEP 2: Create docs/automation_workflow_v2.md
# -------------------------------------------------------------------
workflow_doc_md = """# FL-04: Automation Workflow v2 — Source-Grounded Technical Audit & Case Synthesis Pipeline

> **Core Purpose:** Automate the multi-step research, synthesis, critique, and drafting pipeline for technical case studies and domain briefs using a source-grounded no-code workflow (NotebookLM + Claude Project framing).

---

## 1. System Flow & Architecture Diagram
"""

with open("docs/automation_workflow_v2.md", "w", encoding="utf-8") as f:
    f.write(workflow_doc_md)

print("File created: docs/automation_workflow_v2.md")
# Out:
# File created: docs/automation_workflow_v2.md
