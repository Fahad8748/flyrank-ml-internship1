# %%
What I Built & Explained: Flexible Dataset Ingestion & Column Normalization

What it does: Reads raw search engine performance data from local storage and standardizes column headers before running metrics or machine learning pipelines.

How it works in plain words: Raw datasets often come with varying file formats (.parquet or .csv) and inconsistent column names (like URL vs page_id). The script scans the data directory automatically, converts all column names to lowercase, and uses fallback rules to detect essential variables (pages, keywords, clicks, and rankings).

Why it matters: It prevents key errors and pipeline crashes, ensuring data metrics like traffic concentration and ranking volatility calculate smoothly regardless of minor source file changes.
