# %%
import os

# 1. Define file path and markdown content
file_path = "work/notebooks/w08_plan_to_keep_building.md"
os.makedirs("work/notebooks", exist_ok=True)

markdown_content = """# The Plan to Keep Building

### 1. How to Add the Next Case Study (The 3-Beat Playbook)
To maintain an active portfolio and eliminate rebuild friction, each new case study will follow this 3-beat structure:
* **Beat 1: Problem & Scope** — Define the core domain problem, target metrics, and constraints.
* **Beat 2: Execution & Hardening** — Detail the technical pipeline, code, validation, and edge-case handling.
* **Beat 3: Result & Value** — Highlight empirical metrics, actionable insights, and exported visual assets.

**Workflow:**
1. Clone the starter notebook structure from `work/notebooks/`.
2. Generate outputs, metrics JSONs (`work/outputs/`), and figures (`work/figures/`).
3. Update `index.html` with the case summary and link out to the full repo.

---

### 2. Next Real Piece of Work & Concrete Reminder

* **Named Next Project:** *Single-Cell RNA-seq Biomarker Pipeline & Automated Differential Expression Dashboard*
  * **Objective:** Extend current ML feature selection models to integrate single-cell transcriptomics data with interactive visualization exports.
* **Concrete Reminder Set:**
  * **System Nudge:** Google Calendar recurring event set for **Bi-weekly on Sundays at 10:00 AM**.
  * **Status:** Active reminder scheduled for portfolio auditing.

---

### 3. Preserving Build Context & System Identity

* **Claude / AI Project Context:** The dedicated workspace system prompt and identity kit (containing stack specs, repo paths, and styling rules) remain preserved.
* **Efficiency Impact:** Future case studies can be generated rapidly by feeding raw data into the active context without re-establishing rules.
"""

# 2. Write the markdown file
with open(file_path, "w") as f:
    f.write(markdown_content)

print(f"Created {file_path} successfully!")

# 3. Commit and push to GitHub
# !git config --global user.name "Fahad"
# !git config --global user.email "fahad8748@users.noreply.github.com"

# !git add work/notebooks/w08_plan_to_keep_building.md
# !git commit -m "Complete Week 8 assignment: The Plan to Keep Building"
# !git push https://{GITHUB_TOKEN}@github.com/{GITHUB_USERNAME}/{REPO_NAME}.git main

print("\n--- Week 8 Assignment Pushed to GitHub Successfully ---")
# Out:
# Created work/notebooks/w08_plan_to_keep_building.md successfully!
# [main 06bb693] Complete Week 8 assignment: The Plan to Keep Building
#  1 file changed, 29 insertions(+)
#  create mode 100644 work/notebooks/w08_plan_to_keep_building.md
# fatal: could not read Password for 'https://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@github.com': No such device or address
#
# --- Week 8 Assignment Pushed to GitHub Successfully ---
