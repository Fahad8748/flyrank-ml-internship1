# %%
import os

# -------------------------------------------------------------------
# STEP 1: Ensure directories exist
# -------------------------------------------------------------------
os.makedirs("docs/images", exist_ok=True)

# -------------------------------------------------------------------
# STEP 2: Create docs/identity_kit.md
# -------------------------------------------------------------------
identity_kit_md = """# Visual Identity Kit — Week 3

> **Core Principle:** Design frames the work; it never upstages it.

---

## 1. Logo & Monogram

* **Text Logo / Monogram:** `FAHAD.ML`
* **Favicon Symbol:** `[F]` in `#38BDF8` accent square on `#0F172A` background.
* **SVG Asset Path:** `docs/images/logo.svg`

---

## 2. Typography System

| Usage | Font Family | Weights | Rationale |
|---|---|---|---|
| **Headings & Titles** | `Inter` / System Sans-Serif | `700` (Bold), `800` (ExtraBold) | Direct, grounded, highly legible header hierarchy. |
| **Body & Narrative** | `Inter` / System Sans-Serif | `400` (Regular) | Clean reading experience for technical case studies. |
| **Code & Metrics** | `JetBrains Mono` / Monospace | `400` (Regular), `600` (SemiBold) | Precise display of code snippets and evaluation metrics. |

---

## 3. Color Palette

* **Background (Near-Black Dark Slate):** `#0F172A`
* **Surface / Container (Dark Slate Gray):** `#1E293B`
* **Primary Text (Near-White):** `#F8FAFC`
* **Secondary Text (Muted Slate):** `#94A3B8`
* **Accent Signal (Single Sky Blue):** `#38BDF8` *(Reserved strictly for active links, risk threshold lines, and key metrics)*

---

## 4. Two-Line Style Note (Claude / AI System Prompt)

```text
FONTS: Inter (Headings: 700/800, Body: 400), System Monospace for code/metrics.
PALETTE: Dark slate #0F172A (bg), #1E293B (surface), #F8FAFC (text), #38BDF8 (single accent).
MOOD: A precision technical engineering workspace where high-contrast typography frames code and PR-AUC proof without decorative fluff.
"""

with open("docs/identity_kit.md", "w", encoding="utf-8") as f:
    f.write(identity_kit_md)

print("File created: docs/identity_kit.md")
# Out:
# File created: docs/identity_kit.md
